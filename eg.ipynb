# %%
import requests

# Replace 'demo' with your actual API key
api_key = "1UGCGOW5V20L24UB"
url = f"https://www.alphavantage.co/query?function=WTI&interval=monthly&apikey={api_key}"
response = requests.get(url)

if response.status_code == 200:
    data = response.json()
    print(data)  # Inspect the output
else:
    print(f"Error: {response.status_code} - {response.text}")
# Out:
# {'name': 'Crude Oil Prices WTI', 'interval': 'monthly', 'unit': 'dollars per barrel', 'data': [{'date': '2024-11-01', 'value': '69.95'}, {'date': '2024-10-01', 'value': '71.99'}, {'date': '2024-09-01', 'value': '70.24'}, {'date': '2024-08-01', 'value': '76.68'}, {'date': '2024-07-01', 'value': '81.8'}, {'date': '2024-06-01', 'value': '79.77'}, {'date': '2024-05-01', 'value': '80.02'}, {'date': '2024-04-01', 'value': '85.35'}, {'date': '2024-03-01', 'value': '81.28'}, {'date': '2024-02-01', 'value': '77.25'}, {'date': '2024-01-01', 'value': '74.15'}, {'date': '2023-12-01', 'value': '71.9'}, {'date': '2023-11-01', 'value': '77.69'}, {'date': '2023-10-01', 'value': '85.64'}, {'date': '2023-09-01', 'value': '89.43'}, {'date': '2023-08-01', 'value': '81.39'}, {'date': '2023-07-01', 'value': '76.07'}, {'date': '2023-06-01', 'value': '70.25'}, {'date': '2023-05-01', 'value': '71.58'}, {'date': '2023-04-01', 'value': '79.45'}, {'date': '2023-03-01', 'value': '73.28'}, {'date': '2023-02-01', 'value': '76.83'}, {'date': '2023-01-01', 'value': '78.12'}, {'date': '2022-12-01', 'value': '76.44'}, {'date': '2022-11-01', 'value': '84.37'}, {'date': '2022-10-01', 'value': '87.55'}, {'date': '2022-09-01', 'value': '84.26'}, {'date': '2022-08-01', 'value': '93.67'}, {'date': '2022-07-01', 'value': '101.62'}, {'date': '2022-06-01', 'value': '114.84'}, {'date': '2022-05-01', 'value': '109.55'}, {'date': '2022-04-01', 'value': '101.78'}, {'date': '2022-03-01', 'value': '108.5'}, {'date': '2022-02-01', 'value': '91.64'}, {'date': '2022-01-01', 'value': '83.22'}, {'date': '2021-12-01', 'value': '71.71'}, {'date': '2021-11-01', 'value': '79.15'}, {'date': '2021-10-01', 'value': '81.48'}, {'date': '2021-09-01', 'value': '71.65'}, {'date': '2021-08-01', 'value': '67.73'}, {'date': '2021-07-01', 'value': '72.49'}, {'date': '2021-06-01', 'value': '71.38'}, {'date': '2021-05-01', 'value': '65.17'}, {'date': '2021-04-01', 'value': '61.72'}, {'date': '2021-03-01', 'value': '62.33'}, {'date': '2021-02-01', 'value': '59.04'}, {'date': '2021-01-01', 'value': '52.0'}, {'date': '2020-12-01', 'value': '47.02'}, {'date': '2020-11-01', 'value': '40.94'}, {'date': '2020-10-01', 'value': '39.4'}, {'date': '2020-09-01', 'value': '39.63'}, {'date': '2020-08-01', 'value': '42.34'}, {'date': '2020-07-01', 'value': '40.71'}, {'date': '2020-06-01', 'value': '38.31'}, {'date': '2020-05-01', 'value': '28.56'}, {'date': '2020-04-01', 'value': '16.55'}, {'date': '2020-03-01', 'value': '29.21'}, {'date': '2020-02-01', 'value': '50.54'}, {'date': '2020-01-01', 'value': '57.52'}, {'date': '2019-12-01', 'value': '59.88'}, {'date': '2019-11-01', 'value': '57.03'}, {'date': '2019-10-01', 'value': '53.96'}, {'date': '2019-09-01', 'value': '56.95'}, {'date': '2019-08-01', 'value': '54.81'}, {'date': '2019-07-01', 'value': '57.35'}, {'date': '2019-06-01', 'value': '54.66'}, {'date': '2019-05-01', 'value': '60.83'}, {'date': '2019-04-01', 'value': '63.86'}, {'date': '2019-03-01', 'value': '58.15'}, {'date': '2019-02-01', 'value': '54.95'}, {'date': '2019-01-01', 'value': '51.38'}, {'date': '2018-12-01', 'value': '49.52'}, {'date': '2018-11-01', 'value': '56.96'}, {'date': '2018-10-01', 'value': '70.75'}, {'date': '2018-09-01', 'value': '70.23'}, {'date': '2018-08-01', 'value': '68.06'}, {'date': '2018-07-01', 'value': '70.98'}, {'date': '2018-06-01', 'value': '67.87'}, {'date': '2018-05-01', 'value': '69.98'}, {'date': '2018-04-01', 'value': '66.25'}, {'date': '2018-03-01', 'value': '62.73'}, {'date': '2018-02-01', 'value': '62.23'}, {'date': '2018-01-01', 'value': '63.7'}, {'date': '2017-12-01', 'value': '57.88'}, {'date': '2017-11-01', 'value': '56.64'}, {'date': '2017-10-01', 'value': '51.58'}, {'date': '2017-09-01', 'value': '49.82'}, {'date': '2017-08-01', 'value': '48.04'}, {'date': '2017-07-01', 'value': '46.63'}, {'date': '2017-06-01', 'value': '45.18'}, {'date': '2017-05-01', 'value': '48.48'}, {'date': '2017-04-01', 'value': '51.06'}, {'date': '2017-03-01', 'value': '49.33'},  ...

# %%
import pandas as pd
from sqlalchemy import create_engine, text

# Database connection
DATABASE_URL = "postgresql://postgres:Lazooki1797#@localhost:5432/maritime"
engine = create_engine(DATABASE_URL)

# Identify incorrect oil price values
query_select = """
SELECT * FROM routes;
"""

# Fetch and display incorrect values
with engine.connect() as conn:
    incorrect_values = pd.read_sql_query(query_select, conn)
    print("Incorrect values:")

incorrect_values
# Out:
# Incorrect values:
#     id route                                        description     laydays  \
# 0    1   TD2  270,000mt. Middle East Gulf to Singapore (Ras ...  20/30 days
# 1    2  TD3C  270,000mt. Middle East Gulf to China (Ras Tanu...  15/30 days
# 2    3   TD6  135,000mt. Black Sea to Mediterranean (CPC to ...  10/15 days
# 3    4   TD7  80,000mt. North Sea to Continent (Hound Point ...   7/14 days
# 4    5   TD8  80,000mt crude and/or DPP, heat 135F. Kuwait t...  20/25 days
# 5    6   TD9  70,000mt. Caribbean to US Gulf (Covenas to Cor...   7/14 days
# 6    7  TD14  80,000mt. South East Asia to east coast Austra...  21/25 days
# 7    8  TD15  260,000mt. West Africa to China (Serpentina FP...  20/30 days
# 8    9  TD18  30,000mt fuel oil. Baltic to UK-Cont (Tallinn ...  10/15 days
# 15                 Crude Oil   70000        15        4         1.0
# 16  Clean Petroleum Products   75000        15        4         1.0
# 17  Clean Petroleum Products   37000        15        4         1.0
# 18  Clean Petroleum Products   55000        15        4         1.0
# 19  Clean Petroleum Products   30000        15        4         1.0
# 20  Clean Petroleum Products   35000        15        4         1.0
# 21  Clean Petroleum Products   65000        15        4         1.0
# 22  Clean Petroleum Products   40000        15        4         1.0
# 23  Clean Petroleum Products   40000        15        4         1.0
# 24  Clean Petroleum Products   35000        15        4         1.0
# 25  Clean Petroleum Products   38000        15        4         1.0
# 26  Clean Petroleum Products   80000        15        4         1.0
# 27  Clean Petroleum Products   60000        15        4         1.0
# 28  Clean Petroleum Products   35000        15        4         1.0
# 29  Clean Petroleum Products   38000        15        4         1.0
# 30  Clean Petroleum Products   37000        15        4         1.0
# 31  Clean Petroleum Products   90000        15        4         1.0
# 32  Clean Petroleum Products   38000        15        4         1.0
# 33  Clean Petroleum Products   35000        15        4         1.0
# 34  Clean Petroleum Products   30000        15        4         1.0

# %%
import pandas as pd
from sqlalchemy import create_engine, text

# Database connection
DATABASE_URL = "postgresql://postgres:Lazooki1797#@localhost:5432/maritime"
engine = create_engine(DATABASE_URL)

# Define a list of tables you want to query
tables = ["freight_rates", "macro_data", "news_sentiment"]

# Fetch data from each table and display as DataFrames
with engine.connect() as conn:
    for table in tables:
        query_select = f"SELECT * FROM {table};"
        data_frame = pd.read_sql_query(query_select, conn)
        
        # Display the DataFrame for each table
        print(f"Data from {table}:")
        print(data_frame)
        print("\n")
# Out:
# Data from freight_rates:
#     id route                                        description     laydays  \
# 0    1   TD2  270,000mt. Middle East Gulf to Singapore (Ras ...  20/30 days
# 1    2  TD3C  270,000mt. Middle East Gulf to China (Ras Tanu...  15/30 days
# 2    3   TD6  135,000mt. Black Sea to Mediterranean (CPC to ...  10/15 days
# 3    4   TD7  80,000mt. North Sea to Continent (Hound Point ...   7/14 days
# 4    5   TD8  80,000mt crude and/or DPP, heat 135F. Kuwait t...  20/25 days
# 5    6   TD9  70,000mt. Caribbean to US Gulf (Covenas to Cor...   7/14 days
# 6    7  TD14  80,000mt. South East Asia to east coast Austra...  21/25 days
# 7    8  TD15  260,000mt. West Africa to China (Serpentina FP...  20/30 days
# 8    9  TD18  30,000mt fuel oil. Baltic to UK-Cont (Tallinn ...  10/15 days
# 9   10  TD19  80,000mt. Cross Mediterranean (Ceyhan to Lavera).  10/15 days
# 10  11  TD20  130,000mt. West Africa to UK-Continent (Bonny ...  15/20 days
# 11  12  TD21  50,000mt fuel oil, Caribbean to US Gulf (Mamon...   7/14 days
# 12  13  TD22  270,000mt crude Galveston O/S lightering area ...  25/35 days
# 13  14  TD23            140,000mt Light crude Basrah to Lavera.  20/30 days
# 14  15  TD25  70,000mt crude Corpus Christi-Beaumont / A-R-A...  10/20 days
# 15  16  TD26  70,000mt. EC Mexico to US Gulf (Dos Bocas or C...   5/10 days
# 16  17   TC1  75,000mt CPP/naphtha condensate. Middle East G...  30/35 days
# 17  18   TC2  37,000mt CPP/UNL. Continent to US Atlantic coa...  10/14 days
# 18  19   TC5  55,000mt CPP/UNL naphtha condensate. Middle Ea...  30/35 days
# 19  20   TC6  30,000mt CPP/UNL. Algeria to European Mediterr...   7/14 days
# 20  21   TC7  35,000mt CPP. Singapore to east coast Australi...  17/23 days
# 21  22   TC8  65,000mt CPP/UNL middle distillate. Middle Eas...  20/30 days
# 22  23  TC10  40,000mt CPP/UNL. South Korea to west coast No...  14/21 days
# 23  24  TC11            40,000mt CPP. South Korea to Singapore.  10/17 days
# 24  25  TC12  35,000mt naphtha condensate. West coast India ...   7/14 days
# 25  26  TC14  38,000mt CPP/UNL/diesel. US Gulf to Continent ...   6/12 days
# 26  27  TC15  80,000mt naphtha. Med / Far East (Skikda to Ch...  15/25 days
# 27  28  TC16  60,000mt CPP. A-R-A / West Africa (Amsterdam t...  10/14 days
# 28  29  TC17             35,000mt CPP. Jubail to Dar es Salaam.  10/20 days
# 29  30  TC18  38,000mt CPP/UNL US Gulf to Brazil (Houston to...   6/12 days
# 30  31  TC19  37,000 CPP, A-R-A to West Africa (Amsterdam to...   5/10 days
# 31  32  TC20  90,000mt CPP/UNL middle distillate. Middle Eas...  15/20 days
# 32  33  TC21  38,000mt CPP US Gulf to Caribbean (Houston to ...   5/10 days
# 33  34  TC22  35,000mt CPP/UNL. South Korea to Australia (Ye...  17/23 days
# 34  35  TC23  30,000mt CPP/UNL/ULSD middle distillate. ARA t...   5/10 days
#
#                   cargo_type  volume hull_type  age_max  commission
# 0                  Crude Oil  270000        15        4         1.0
# 1                  Crude Oil  270000        15        4         1.0
# 2                  Crude Oil  135000        15        4         1.0
# 3                  Crude Oil   80000        15        4         1.0
# 4                  Crude Oil   80000        15        4         1.0
# 5                  Crude Oil   70000        15        4         1.0
# 6                  Crude Oil   80000        15        4         1.0
# 7                  Crude Oil  260000        15        4         1.0
# 8                   Fuel Oil   30000        15        4         1.0
# 9                  Crude Oil   80000        15        4         1.0
# 10                 Crude Oil  130000        15        4         1.0
# 11                  Fuel Oil   50000        15        4         1.0
# 12                 Crude Oil  270000        15        4         1.0
# 13                 Crude Oil  140000        15        4         1.0
# 14                 Crude Oil   70000        15        4         1.0
# 15                 Crude Oil   70000        15        4         1.0
# 16  Clean Petroleum Products   75000        15        4         1.0
# 17  Clean Petroleum Products   37000        15        4         1.0
# 18  Clean Petroleum Products   55000        15        4         1.0
# 19  Clean Petroleum Products   30000        15        4         1.0
# 20  Clean Petroleum Products   35000        15        4         1.0
# 21  Clean Petroleum Products   65000        15        4         1.0
# 22  Clean Petroleum Products   40000        15        4         1.0
# 23  Clean Petroleum Products   40000        15        4         1.0
# 24  Clean Petroleum Products   35000        15        4         1.0
# 25  Clean Petroleum Products   38000        15        4         1.0
# 26  Clean Petroleum Products   80000        15        4         1.0
# 27  Clean Petroleum Products   60000        15        4         1.0
# 28  Clean Petroleum Products   35000        15        4         1.0
# 29  Clean Petroleum Products   38000        15        4         1.0
# 30  Clean Petroleum Products   37000        15        4         1.0
# 31  Clean Petroleum Products   90000        15        4         1.0
# 32  Clean Petroleum Products   38000        15        4         1.0
# 33  Clean Petroleum Products   35000        15        4         1.0
# 34  Clean Petroleum Products   30000        15        4         1.0
#
#
# Data from macro_data:
#         id        date          metric        value
# 0     4171  2024-07-01      GDP Growth  5866.841000
# 1     4172  2024-04-01      GDP Growth  5817.169000
# 2     4173  2024-01-01      GDP Growth  5638.455000
# 3     4174  2023-10-01      GDP Growth  5831.583000
# 4     4175  2023-07-01      GDP Growth  5724.051000
# ...    ...         ...             ...          ...
# 1367  5538  2024-12-30  News Sentiment     0.053679
# 1368  5539  2024-12-30  News Sentiment     0.026721
# 1369  5540  2024-12-30  News Sentiment     0.026825
# 1370  5541  2024-12-30  News Sentiment     0.034399
# 1371  5542  2024-12-30  News Sentiment     0.002457
#
# [1372 rows x 4 columns]
#
#
# Data from news_sentiment:
#         id                                              topic  \
# 0     2192                                      freight rates
# 1        2                                      freight rates
# 2     2193                                      freight rates
# 3     2194                                      freight rates
# 4     2195                                      freight rates
# ...    ...                                                ...
# 3988  6087  {"freight rates","global shipping demand","con...
# 3989  6088  {"freight rates","global shipping demand","con...
# 3990  6089  {"freight rates","global shipping demand","con...
# 3991  6090  {"freight rates","global shipping demand","con...
# 3992  6091  {"freight rates","global shipping demand","con...
#
#                 source                                             author  \
# 0     Business Insider                                     Benjamin Zhang
# 1            [Removed]                                               None
# 2               Forbes  Joe Cornell, Contributor, \n Joe Cornell, Cont...
# 3            [Removed]                                               None
# 4               Forbes  John Tamny, Contributor, \n John Tamny, Contri...
# ...                ...                                                ...
# 3988     Investing.com                                      Investing.com
# 3989     GlobeNewswire                                    Thor Industries
# 3990         The Punch                                            Opinion
# 3991         The Punch                                            Opinion
# 3992    Financial Post                                     Bloomberg News
#
#                                                   title  \
# 0     I drove a $63,000 Infiniti QX60. It's a stylis...
# 1                                             [Removed]
# 2     FedEx Corporation To Spin-Off FedEx Freight Bu...
# 3                                             [Removed]
# 4     DOGE’s Greater Potential Will Arguably Be Foun...
# ...                                                 ...
# 3988  Algorhythm Holdings announces $2 million stock...
# 3989  THOR Industries Announces Regular Quarterly Di...
# 3990  Revitalising Nigeria’s economy through manufac...
# 3991  Revitalising Nigeria’s economy through manufac...
# 3992  US Stock Futures Pare Drop After Data; Bonds G...
#
#                                             description  \
# 0     I drove a 2025 Infiniti QX60 luxury SUV in Lux...
# 1                                             [Removed]
# 2     The Company intends to execute the planned sep...
# 3                                             [Removed]
# 4     Call the early railroads assembly lines on whe...
# ...                                                 ...
# 3988  Algorhythm Holdings announces $2 million stock...
# 3989  ELKHART, Ind., Dec. 19, 2024 (GLOBE NEWSWIRE) ...
# 3990  Nigeria is currently facing severe economic ch...
# 3991  Nigeria is currently facing severe economic ch...
# 3992  US stock futures trimmed earlier losses after ...
#
#                                                 content published_at  \
# 0     The 2025 Infiniti QX60 Luxe Black Edition.Benj...   2024-12-16
# 1                                             [Removed]   2024-12-16
# 2     (Photo by Robert Alexander/Getty Images)\r\nGe...   2024-12-27
# 3                                             [Removed]   2024-12-16
# 4     SAN BERNARDINO, CA - MAY 15: A freight train p...   2024-12-13
# ...                                                 ...          ...
# 3988  FORT LAUDERDALE - Algorhythm Holdings, Inc. (N...   2024-12-17
# 3989  ELKHART, Ind., Dec. 19, 2024 (GLOBE NEWSWIRE) ...   2024-12-19
# 3990  Nigeria is currently facing severe economic ch...   2024-12-09
# 3991  Nigeria is currently facing severe economic ch...   2024-12-11
# 3992  US stock futures trimmed earlier losses after ...   2024-12-20
#
#                                                     url  sentiment_score
# 0     https://www.businessinsider.com/infiniti-qx60-...              NaN
# 1                                   https://removed.com              NaN
# 2     https://www.forbes.com/sites/joecornell/2024/1...              NaN
# 3                                   https://removed.com              NaN
# 4     https://www.forbes.com/sites/johntamny/2024/12...              NaN
# ...                                                 ...              ...
# 3988  https://www.investing.com/news/company-news/al...           0.0000
# 3989  https://www.globenewswire.com/news-release/202...           0.7783
# 3990  https://punchng.com/revitalising-nigerias-econ...          -0.7269
# 3991  https://punchng.com/revitalising-nigerias-econ...          -0.7269
# 3992  https://financialpost.com/pmn/business-pmn/us-...          -0.0586
#
# [3993 rows x 10 columns]

# %%
import pandas as pd
from sqlalchemy import create_engine

# Database connection
DATABASE_URL = "postgresql://postgres:Lazooki1797#@localhost:5432/maritime"
engine = create_engine(DATABASE_URL)

# Query to fetch the data
query_select = "SELECT * FROM macro_data WHERE metric = 'news_sentiment';"

# Fetch data and display as a DataFrame
with engine.connect() as conn:
    routes_df = pd.read_sql_query(query_select, conn)

# Display the DataFrame
routes_df.head()
# Out:
# Empty DataFrame
# Columns: [id, date, metric, value]
# Index: []

# %%
routes_df.head(20)
# Out:
# Empty DataFrame
# Columns: [id, date, metric, value]
# Index: []

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_sentiment_trends():
    query = """
        SELECT published_at, sentiment_score
        FROM news_sentiment
        WHERE published_at >= NOW() - INTERVAL '14 days'
        ORDER BY published_at
    """
    df = pd.read_sql_query(query, con=engine)

    if not df.empty:
        df['published_at'] = pd.to_datetime(df['published_at'])
        df.set_index('published_at', inplace=True)

        plt.figure(figsize=(10, 6))
        plt.plot(df.index, df['sentiment_score'], marker='o', linestyle='-', label='Sentiment Score')
        plt.title('Sentiment Trends Over Last 14 Days')
        plt.xlabel('Date')
        plt.ylabel('Sentiment Score')
        plt.legend()
        plt.grid()
        plt.show()
    else:
        print("No data available for the specified period.")

# %%
plot_sentiment_trends()
# Out:
# No data available for the specified period.

# %%
def truncate_routes_table():
    query = text("TRUNCATE TABLE routes;")
    with engine.connect() as connection:
        connection.execute(query)
    print("Table 'routes' truncated successfully.")

# Example usage
if __name__ == "__main__":
    truncate_routes_table()
# Out:
# Table 'routes' truncated successfully.

# %%
import pandas as pd
from sqlalchemy import text

def fetch_recent_news_sentiments():
    query = text("""
        SELECT * FROM routes;
    """)
    with engine.connect() as connection:
        # Execute the query and fetch all rows
        result = connection.execute(query)
        data = result.fetchall()

        # Get column names from the result
        columns = result.keys()

    # Convert the result into a Pandas DataFrame
    df = pd.DataFrame(data, columns=columns)
    return df

# Example usage
if __name__ == "__main__":
    df = fetch_recent_news_sentiments()

# %%
import pandas as pd
from sqlalchemy import create_engine

# Database connection
DATABASE_URL = "postgresql://postgres:Lazooki1797#@localhost:5432/maritime"
engine = create_engine(DATABASE_URL)

# Tanker type thresholds
TANKER_THRESHOLDS = {
    "VLCC": 200000,
    "Suezmax": 120000,
    "Aframax": 80000,
    "LR2": 80000,
    "LR1": 55000,
    "MR": 25000
}

# Mock function for rates and % changes
def mock_freight_data(volume):
    current_rate = round(20000 + (volume * 0.01), 2)
    change_percent = round((0.05 if volume > 150000 else 0.03) * 100, 2)
    return current_rate, change_percent

# Classify tanker type
def classify_tanker_type(volume):
    for tanker, threshold in TANKER_THRESHOLDS.items():
        if volume >= threshold:
            return tanker
    return "Unknown"

# Fetch, process, and format data
def fetch_and_format_routes():
    query = "SELECT route, description, cargo_type, volume FROM routes"
    routes_df = pd.read_sql_query(query, con=engine)
    
    # Classify tanker types
    routes_df["Tanker Type"] = routes_df["volume"].apply(classify_tanker_type)
    
    # Add mock rates and % changes
    routes_df[["Current Rate ($/day)", "% Change (2 weeks)"]] = routes_df.apply(
        lambda row: pd.Series(mock_freight_data(row["volume"])), axis=1
    )
    
    # Group and format data
    grouped_data = []
    for cargo_type, group in routes_df.groupby("cargo_type"):
        for tanker_type, tanker_group in group.groupby("Tanker Type"):
            grouped_data.append((cargo_type, tanker_type, tanker_group))
    
    return grouped_data

# Run and display in Jupyter
grouped_routes = fetch_and_format_routes()

for cargo_type, tanker_type, df in grouped_routes:
    print(f"### {cargo_type} - {tanker_type}")
    display(df[["route", "Current Rate ($/day)", "% Change (2 weeks)", "volume"]])
# Out:
# ### Clean Petroleum Products - Aframax
#    route  Current Rate ($/day)  % Change (2 weeks)  volume
# 26  TC15               20800.0                 3.0   80000
# 31  TC20               20900.0                 3.0   90000
# 61  TC15               20800.0                 3.0   80000
# 66  TC20               20900.0                 3.0   90000
# ### Clean Petroleum Products - LR1
#    route  Current Rate ($/day)  % Change (2 weeks)  volume
# 16   TC1               20750.0                 3.0   75000
# 18   TC5               20550.0                 3.0   55000
# 21   TC8               20650.0                 3.0   65000
# 27  TC16               20600.0                 3.0   60000
# 51   TC1               20750.0                 3.0   75000
# 53   TC5               20550.0                 3.0   55000
# 56   TC8               20650.0                 3.0   65000
# 62  TC16               20600.0                 3.0   60000
# ### Clean Petroleum Products - MR
